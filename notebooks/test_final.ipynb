# %% [markdown]
# # Test final package

# %%
from SRGANupscaling.main import super_resolution
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
uploaded_file='/Users/sridhargk/code/sridhar211/SRGANupscaling/raw_data/tem.jpg'
image = Image.open(uploaded_file)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=85x94 at 0x1EF45E400>

# %%
super=super_resolution(image)
super
# Out:
# <PIL.Image.Image image mode=RGB size=340x376 at 0x1EE8D8BE0>

# %%
plt.figure(figsize=(10, 15))
plt.subplot(221)
plt.title('Original Image')
plt.imshow(image)
plt.axis('off')
plt.subplot(222)
plt.title('Super Resolution Image')
plt.imshow(super)
plt.axis('off')
plt.show();
