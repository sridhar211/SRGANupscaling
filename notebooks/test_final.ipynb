# %% [markdown]
# # Test final package

# %%
from SRGANupscaling.main import super_resolution
from PIL import Image
import numpy as np

# %%
uploaded_file='/Users/sridhargk/code/sridhar211/SRGANupscaling/raw_data/set5/woman.png'
image = Image.open(uploaded_file)

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=57x84 at 0x10F249F40>

# %%
super_resolution(image)
# Out:
# 2022-07-15 17:28:35.908275: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-15 17:28:38.968167: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# <PIL.Image.Image image mode=RGB size=228x336 at 0x1F07AC910>
