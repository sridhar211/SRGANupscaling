# %% [markdown]
# # A notebook to test our package and functions

# %% [markdown]
# ### Import modules from our package

# %%
from SRGANupscaling.data import get_images_gcp, plot_image_comparison, plot_encode_comparison
from SRGANupscaling.params import STORAGE_LOCATION_KAGGLE_ORG_LR, STORAGE_LOCATION_KAGGLE_ORG_HR
from SRGANupscaling.params import STORAGE_LOCATION_KAGGLE_LR, STORAGE_LOCATION_KAGGLE_HR
from SRGANupscaling.params import STORAGE_LOCATION_FLICKR_LR, STORAGE_LOCATION_FLICKR_HR
from SRGANupscaling.model import image_upscale, image_auto_encode

# %% [markdown]
# ### Read `n` images from GCP

# %%
n=20
lr_images=get_images_gcp(n,storage_location=STORAGE_LOCATION_KAGGLE_LR)
hr_images=get_images_gcp(n,storage_location=STORAGE_LOCATION_KAGGLE_ORG_HR)

# %% [markdown]
# ### Use model to upscale : input array of low res images(batch_size, height, width, rgb_channels)

# %%
sr_images = image_upscale(lr_images)
# Out:
# 2022-07-14 15:38:25.219352: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-14 15:38:28.181059: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)

# %% [markdown]
# ### Function to plot comparison of images

# %%
idx=18
plot_image_comparison(lr_images[idx],sr_images[idx],hr_images[idx])

# %%
auto_images = image_auto_encode(sr_images)
plot_encode_comparison(sr_images[idx],auto_images[idx])
