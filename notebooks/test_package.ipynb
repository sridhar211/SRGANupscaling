# %% [markdown]
# # A notebook to test our package and functions

# %% [markdown]
# ### Import modules from our package

# %%
from SRGANupscaling.data import get_images_gcp, plot_image_comparison
from SRGANupscaling.params import STORAGE_LOCATION_KAGGLE_ORG_LR, STORAGE_LOCATION_KAGGLE_ORG_HR
from SRGANupscaling.model import image_upscale
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/melissasiddle/code/sridhar211/SRGANupscaling/notebooks/test_package.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/melissasiddle/code/sridhar211/SRGANupscaling/notebooks/test_package.ipynb#ch0000002?line=0'>1</a> from SRGANupscaling.data import get_images_gcp, plot_image_comparison
#       <a href='vscode-notebook-cell:/Users/melissasiddle/code/sridhar211/SRGANupscaling/notebooks/test_package.ipynb#ch0000002?line=1'>2</a> from SRGANupscaling.params import STORAGE_LOCATION_KAGGLE_ORG_LR, STORAGE_LOCATION_KAGGLE_ORG_HR
#       <a href='vscode-notebook-cell:/Users/melissasiddle/code/sridhar211/SRGANupscaling/notebooks/test_package.ipynb#ch0000002?line=2'>3</a> from SRGANupscaling.model import image_upscale
#
# ModuleNotFoundError: No module named 'SRGANupscaling'

# %% [markdown]
# ### Read `n` images from GCP

# %%
n=5
lr_images=get_images_gcp(n,storage_location=STORAGE_LOCATION_KAGGLE_ORG_LR)
hr_images=get_images_gcp(n,storage_location=STORAGE_LOCATION_KAGGLE_ORG_HR)

# %% [markdown]
# ### Use model to upscale : input array of low res images(batch_size, height, width, rgb_channels)

# %%
sr_images = image_upscale(lr_images)
# Out:
# 2022-07-13 14:27:16.078996: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-13 14:27:19.153083: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)

# %% [markdown]
# ### Function to plot comparison of images

# %%
idx=1
plot_image_comparison(lr_images[idx],sr_images[idx],hr_images[idx])
